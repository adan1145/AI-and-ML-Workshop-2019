# %% [markdown]
# ## What is Machine Learning?
# ## The Machine Learning Process and workflow
# ##  Introduction to Scikit-learn
# ##  Examples of ML workflows with Scikit-learn
# ##  KNN Algorithm
# ##  Commonly used distance measures
# ##  Introduction to Decision Tree Algorithm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### A typical workflow for standard application programming
# ![image.png](attachment:image.png)

# %% [markdown]
# #### A typical ML workflow
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Automatically adapting ML workflow
# ![image.png](attachment:image.png)
#
#
#
#
# Figures source: Hands-on ML with Sciikit-learn 2ed: Oreilly 2019

# %% [markdown]
# ##  Types of ML
# * Supervised Learning
# * Un-supervised Learning
# * Reinforcement Learning
# * Semi-supervised
#
#
# * Another categorization is based on Whether or not the model can learn incrementally on the fly (online versus batch learning)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ML for Understanding a complex problem better (Data Mining)

# %% [markdown]
# ![image.png](attachment:image.png)
